# %% [markdown]
# <h>Подключаем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Импортируем файлы

# %%
df = pd.read_csv('../data/_data.csv')
df.head(5)
# Out:
#    Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0           0       271271157                 4  Квартира
# 1           1       271634126                 4  Квартира
# 2           2       271173086   4, Оба варианта  Квартира
# 3           3       272197456   4, Оба варианта  Квартира
# 4           4       273614615                 2  Квартира
#
#                           Метро                             Адрес  \
# 0  м. Смоленская (9 мин пешком)     Москва, улица Новый Арбат, 27
# 1  м. Смоленская (8 мин пешком)     Москва, улица Новый Арбат, 27
# 2  м. Смоленская (7 мин пешком)     Москва, улица Новый Арбат, 27
# 3  м. Смоленская (3 мин пешком)  Москва, переулок Плотников, 21С1
# 4   м. Арбатская (7 мин пешком)     Москва, улица Новый Арбат, 15
#
#        Площадь, м2                        Дом   Парковка  \
# 0       200.0/20.0           5/16, Монолитный  подземная
# 1  198.0/95.0/18.0  5/16, Монолитно-кирпичный  подземная
# 2  200.0/116.0/4.0                       5/16  подземная
# 3  170.0/95.0/17.0                        5/6  подземная
# 4    58.0/38.0/5.0           12/26, Панельный        NaN
#
#                                                 Цена  ...             Окна  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...              NaN
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...  На улицу и двор
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...  На улицу и двор
# 3  400000.0 руб./ За месяц, Залог - 400000 руб., ...  ...  На улицу и двор
# 4  225000.0 руб./ За месяц, Залог - 225000 руб., ...  ...  На улицу и двор
#
#                            Санузел           Можно с детьми/животными  \
# 0                              NaN  Можно с детьми, Можно с животными
# 1  Совмещенный (2), Раздельный (1)                     Можно с детьми
# 2                  Совмещенный (3)                     Можно с детьми
# 3                  Совмещенный (3)                  Можно с животными
# 4                  Совмещенный (2)                                NaN
#
#                                        Дополнительно        Название ЖК  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 2  Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 3  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                NaN
# 4  Мебель в комнатах, Мебель на кухне, Ванна, Душ...           The Book
#
#   Серия дома Высота потолков, м                Лифт Мусоропровод  \
# 0        NaN                3.0  Пасс (4), Груз (1)           Да
# 1        NaN                3.5  Пасс (1), Груз (1)          Нет
# 2        NaN                3.2            Пасс (1)          NaN
# 3        NaN                3.2            Пасс (1)          NaN
# 4        NaN                3.9  Пасс (1), Груз (1)           Да
#
#                       Ссылка на объявление
# 0  https://www.cian.ru/rent/flat/271271157
# 1  https://www.cian.ru/rent/flat/271634126
# 2  https://www.cian.ru/rent/flat/271173086
# 3  https://www.cian.ru/rent/flat/272197456
# 4  https://www.cian.ru/rent/flat/273614615
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23368 entries, 0 to 23367
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                23368 non-null  int64
#  1   ID  объявления            23368 non-null  int64
#  2   Количество комнат         22327 non-null  object
#  3   Тип                       23368 non-null  object
#  4   Метро                     22053 non-null  object
#  5   Адрес                     23368 non-null  object
#  6   Площадь, м2               23368 non-null  object
#  7   Дом                       23368 non-null  object
#  8   Парковка                  9951 non-null   object
#  9   Цена                      23368 non-null  object
#  10  Телефоны                  23368 non-null  object
#  11  Описание                  23368 non-null  object
#  12  Ремонт                    20613 non-null  object
#  13  Площадь комнат, м2        14458 non-null  object
#  14  Балкон                    15390 non-null  object
#  15  Окна                      16755 non-null  object
#  16  Санузел                   20696 non-null  object
#  17  Можно с детьми/животными  17272 non-null  object
#  18  Дополнительно             23011 non-null  object
#  19  Название ЖК               5848 non-null   object
#  20  Серия дома                2163 non-null   object
#  21  Высота потолков, м        11206 non-null  float64
#  22  Лифт                      17868 non-null  object
#  23  Мусоропровод              12846 non-null  object
#  24  Ссылка на объявление      23368 non-null  object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  ID  объявления  Высота потолков, м
# count  23368.000000    2.336800e+04         11206.00000
# mean   11683.500000    2.676265e+08             2.98345
# std     6745.904881    1.876862e+07             7.61472
# min        0.000000    1.072986e+08             1.20000
# 25%     5841.750000    2.712663e+08             2.64000
# 50%    11683.500000    2.739030e+08             2.64000
# 75%    17525.250000    2.746872e+08             2.80000
# max    23367.000000    2.750064e+08           320.00000

# %% [markdown]
# Типы данных

# %%
df.dtypes.value_counts()
# Out:
# object     22
# int64       2
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# Уникальные значения

# %%
df.applymap(type).nunique()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23112\1465807234.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(type).nunique()
# Unnamed: 0                  1
# ID  объявления              1
# Количество комнат           2
# Тип                         1
# Метро                       2
# Адрес                       1
# Площадь, м2                 1
# Дом                         1
# Парковка                    2
# Цена                        1
# Телефоны                    1
# Описание                    1
# Ремонт                      2
# Площадь комнат, м2          2
# Балкон                      2
# Окна                        2
# Санузел                     2
# Можно с детьми/животными    2
# Дополнительно               2
# Название ЖК                 2
# Серия дома                  2
# Высота потолков, м          1
# Лифт                        2
# Мусоропровод                2
# Ссылка на объявление        1
# dtype: int64

# %% [markdown]
# Числовые значения

# %%
numeric = df.select_dtypes(include='number')
numeric
# Out:
#        Unnamed: 0  ID  объявления  Высота потолков, м
# 0               0       271271157                3.00
# 1               1       271634126                3.50
# 2               2       271173086                3.20
# 3               3       272197456                3.20
# 4               4       273614615                3.90
# ...           ...             ...                 ...
# 23363       23363       215565511                 NaN
# 23364       23364       274654844                 NaN
# 23365       23365       268679909                 NaN
# 23366       23366       274807525                2.65
# 23367       23367       274672243                 NaN
#
# [23368 rows x 3 columns]

# %% [markdown]
# Проверим на пропуски

# %%
missed = df.isna().sum()
fig, ax = plt.subplots()
sns.barplot(x=missed.index, y=missed.values)
ax.set_title('Пропуски в колонках')
plt.xticks(rotation=40, ha='right')

# %% [markdown]
# Первая колонка просто нумерация строк

# %%
df = df.drop(columns=["Unnamed: 0"])
df.head(1)
# Out:
#    ID  объявления Количество комнат       Тип                         Метро  \
# 0       271271157                 4  Квартира  м. Смоленская (9 мин пешком)
#
#                            Адрес Площадь, м2               Дом   Парковка  \
# 0  Москва, улица Новый Арбат, 27  200.0/20.0  5/16, Монолитный  подземная
#
#                                                 Цена      Телефоны  ... Окна  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...  +79166369231  ...  NaN
#
#   Санузел           Можно с детьми/животными  \
# 0     NaN  Можно с детьми, Можно с животными
#
#                                        Дополнительно        Название ЖК  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
#
#   Серия дома Высота потолков, м                Лифт Мусоропровод  \
# 0        NaN                3.0  Пасс (4), Груз (1)           Да
#
#                       Ссылка на объявление
# 0  https://www.cian.ru/rent/flat/271271157
#
# [1 rows x 24 columns]

# %% [markdown]
# Корреляция между признаками (числовыми и категориальными)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Сколько уникальных в каждой колонке

# %%
df.nunique(dropna=False).sort_values(ascending=False)
# Out:
# ID  объявления              23368
# Ссылка на объявление        23368
# Описание                    23078
# Телефоны                    13172
# Адрес                       12850
# Площадь, м2                 11255
# Метро                        5867
# Площадь комнат, м2           3991
# Цена                         3922
# Дом                          2565
# Название ЖК                  1799
# Дополнительно                 529
# Серия дома                    394
# Высота потолков, м             96
# Лифт                           35
# Количество комнат              25
# Санузел                        21
# Балкон                         19
# Парковка                        6
# Ремонт                          5
# Можно с детьми/животными        4
# Окна                            4
# Мусоропровод                    3
# Тип                             1
# dtype: int64

# %% [markdown]
# Тип можем удалить так не повлияет на наш анализ

# %% [markdown]
# Общая информация по колнкам

# %%
pd.DataFrame({
    "Тип данных": df.dtypes,
    "Кол-во значений": df.count(),
    "Пропуски (шт.)": df.isna().sum(),
    "Пропуски (%)": (df.isna().mean() * 100).round(2),
    "Уникальных значений": df.nunique(),
    "Частое значение": df.mode().iloc[0]
})
# Out:
#                          Тип данных  Кол-во значений  Пропуски (шт.)  \
# ID  объявления                int64            23368               0
# Количество комнат            object            22327            1041
# Тип                          object            23368               0
# Метро                        object            22053            1315
# Адрес                        object            23368               0
# Площадь, м2                  object            23368               0
# Дом                          object            23368               0
# Парковка                     object             9951           13417
# Цена                         object            23368               0
# Телефоны                     object            23368               0
# Описание                     object            23368               0
# Ремонт                       object            20613            2755
# Площадь комнат, м2           object            14458            8910
# Балкон                       object            15390            7978
# Окна                         object            16755            6613
# Санузел                      object            20696            2672
# Можно с детьми/животными     object            17272            6096
# Дополнительно                object            23011             357
# Название ЖК                  object             5848           17520
# Серия дома                   object             2163           21205
# Высота потолков, м          float64            11206           12162
# Лифт                         object            17868            5500
# Мусоропровод                 object            12846           10522
# Ссылка на объявление         object            23368               0
#
#                           Пропуски (%)  Уникальных значений  \
# ID  объявления                    0.00                23368
# Количество комнат                 4.45                   24
# Тип                               0.00                    1
# Метро                             5.63                 5866
# Адрес                             0.00                12850
# Площадь, м2                       0.00                11255
# Дом                               0.00                 2565
# Парковка                         57.42                    5
# Цена                              0.00                 3922
# Телефоны                          0.00                13172
# Описание                          0.00                23078
# Ремонт                           11.79                    4
# Площадь комнат, м2               38.13                 3990
# Балкон                           34.14                   18
# Окна                             28.30                    3
# Санузел                          11.43                   20
# Можно с детьми/животными         26.09                    3
# Дополнительно                     1.53                  528
# Название ЖК                      74.97                 1798
# Серия дома                       90.74                  393
# Высота потолков, м               52.05                   95
# Лифт                             23.54                   34
# Мусоропровод                     45.03                    2
# Ссылка на объявление              0.00                23368
#
#                                                             Частое значение
# ID  объявления                                                    107298592
# Количество комнат                                                         1
# Тип                                                                Квартира
# Метро                                      м. Академическая (10 мин пешком)
# Адрес                                        Москва, Чапаевский переулок, 3
# Площадь, м2                                                  40.0/20.0/10.0
# Дом                                                          3/5, Кирпичный
# Парковка                                                           наземная
# Цена                      40000.0 руб./ За месяц, Залог - 40000 руб., Ко...
# Телефоны                                                       +79819217172
# Описание                                                                  0
# Ремонт                                                        Косметический
# Площадь комнат, м2                                                       20
# Балкон                                                           Балкон (1)
# Окна                                                                Во двор
# Санузел                                                     Совмещенный (1)
# Можно с детьми/животными                                     Можно с детьми
# Дополнительно             Мебель в комнатах, Мебель на кухне, Ванна, Сти...
# Название ЖК                                                    Символ, 2019
# Серия дома                                            индивидуальный проект
# Высота потолков, м                                                     2.64
# Лифт                                                               Пасс (1)
# Мусоропровод                                                             Да
# Ссылка на объявление                 https://www.cian.ru/rent/flat/13194670

# %% [markdown]
# Визуализация вариантивности значений в колонках с мин.колл-вом значений.

# %%
var_cols = ["Парковка", "Балкон", "Мусоропровод", "Ремонт", "Лифт", 'Количество комнат', "Окна", "Можно с детьми/животными"]

#plt.figure(figsize=(12, 4 * len(var_cols)))

for i, col in enumerate(var_cols, 1):
    #plt.subplot(len(var_cols), 1, i)
    plt.figure()

    counts = df[col].fillna("Нет данных").value_counts().head(8)

    sns.barplot(x=counts.values, y=counts.index)
    plt.title(f"Топ-8 значений: {col}")
    plt.xlabel("Количество")
    plt.ylabel("")
    plt.grid()
    plt.tight_layout()

plt.show()

# %% [markdown]
# Вид дома не корректнотно отображался, т.к не было разделения по запятой

# %%
counts = df['Дом'].str.split(',').str[-1].str.strip().value_counts().head(5)

sns.barplot(x=counts.values, y=counts.index)
plt.title('Топ-5 типов домов')
plt.xlabel('Количество')
plt.ylabel('')
plt.show()

# %% [markdown]
# Тут наглядно можем посомтреть какие колонки нужно будет перевести в числовой формат, какие можем удалить, в каких корректнее выбрать моду или медиану.

# %%
df['Площадь м2 числ'] = df['Площадь, м2'].str.split('/').str[0].astype(float)

plt.figure(figsize=(10, 5))
sns.scatterplot(x='Площадь м2 числ', y='Высота потолков, м', data=df)
plt.title('Зависимость высоты потолков от площади квартиры')
plt.xlabel('Площадь, м2')
plt.ylabel('Высота потолков, м')
plt.show()

# %% [markdown]
# По отклонениям делаем вывод, что данне не приведены к общему виду.
